# %% [markdown]
# ## Clasificador MNIST

# %%
# %run load_models.py

# %%
img = 'Camilo_4'
mi_numero(externo=True, path = './images/' + img + '.png', base=None, fila=999, resultados=True)
# Out:
# resultado del knn es : [4]
# resultado regresión logística es :  [4]
# resultado Red Neuronal es :  4
# (array([4], dtype=int64), array([4], dtype=int64), 4)

# %%
mi_numero(externo=False, path = None, base=X_test, fila=8765, resultados=True)
# Out:
# resultado del knn es : [6]
# resultado regresión logística es :  [6]
# resultado Red Neuronal es :  6
# (array([6], dtype=int64), array([6], dtype=int64), 6)

# %%
path = './images/foto_nums6.png'
find_nums(path)
